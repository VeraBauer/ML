# %%
# !pip install streamlit
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install mathplotlib
# Out:
# ERROR: Could not find a version that satisfies the requirement mathplotlib (from versions: none)
# ERROR: No matching distribution found for mathplotlib
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Подготовка данных и модели

# %%
import pandas as pd
data = pd.read_csv('..\data\smoke_detector.csv')
data.drop(data.columns[[0]], axis=1, inplace=True)
data
# Out:
#                 UTC  Temperature[C]  Humidity[%]  TVOC[ppb]  eCO2[ppm]
# 0      1.654733e+09          20.000        57.36        0.0      400.0  \
# 1      1.654733e+09          20.015        56.67        0.0      400.0
# 2      1.654733e+09          20.029        55.96        0.0      400.0
# 3      1.654733e+09          20.044        55.28        0.0      400.0
# 4      1.654733e+09          20.059        54.69        0.0      400.0
# ...             ...             ...          ...        ...        ...
# 62625  1.655130e+09          18.438        15.79      625.0      400.0
# 62626  1.655130e+09          18.653        15.87      612.0      400.0
# 62627  1.655130e+09          18.867        15.84      627.0      400.0
# 62628  1.655130e+09          19.083        16.04      638.0      400.0
# 62629  1.655130e+09          19.299        16.52      643.0      400.0
#
#         Raw H2  Raw Ethanol  Pressure[hPa]  PM1.0  PM2.5  NC0.5  NC1.0  NC2.5
# ...

# %%
import pickle
knn_model = pickle.load(open('../models/KNN_model', 'rb'))
bagging_model =  pickle.load(open('../models/bagging_classification_model', 'rb'))
neuro_model = pickle.load(open('../models/Neuro_classification_model', 'rb'))

# %%
# !streamlit run Главная.py
