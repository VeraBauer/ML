# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/mumbai_houses_task.csv')
#data.drop(['Unnamed: 0'], axis=1, inplace=True)
display(df)
s=pd.get_dummies(df)
#s.to_csv('.../data/one-hot_encoded_mumbai_houses_task.csv', index=False)
df = pd.get_dummies(df)
display(df)
# Out:
#            price    area   latitude  longitude  Bedrooms  Bathrooms  Balcony
# 0     22400000.0   629.0  19.032800  72.896357       2.0        2.0      0.0  \
# 1     35000000.0   974.0  19.032800  72.896357       3.0        2.0      0.0
# 2     31700000.0   968.0  19.085600  72.909277       3.0        3.0      0.0
# 3     18700000.0   629.0  19.155756  72.846862       2.0        2.0      2.0
# 4     13500000.0  1090.0  19.177555  72.849887       2.0        2.0      0.0
# ...          ...     ...        ...        ...       ...        ...      ...
# 6250  19500000.0   810.0  19.138320  72.810020       2.0        2.0      0.0
# 6251  22000000.0  1400.0  19.221920  72.854250       3.0        3.0      1.0
# 6252  20000000.0   750.0  19.144320  72.824111       2.0        2.0      0.0
# 6253  11000000.0   700.0  19.047201  72.872225       2.0        2.0      0.0
# 6254  15000000.0   900.0  19.168818  72.936375       2.0        2.0      0.0
#
#                   Status      neworold  parking Furnished_status  Lift
# 0     Under Construction  New Property      0.0              NaN   0.0  \
# 1     Under Construction  New Property      0.0              NaN   0.0
# 2     Under Construction  New Property      0.0              NaN   0.0
# 3          Ready to Move  New Property      2.0              NaN   2.0
# 4                    NaN  New Property      0.0      Unfurnished   0.0
# ...                  ...           ...      ...              ...   ...
# 6250       Ready to Move        Resale      0.0   Semi-Furnished   0.0
# 6251       Ready to Move        Resale      1.0      Unfurnished   1.0
# 6252       Ready to Move        Resale      0.0              NaN   0.0
# 6253       Ready to Move        Resale      0.0        Furnished   0.0
# 6254       Ready to Move        Resale      0.0              NaN   0.0
#
#      type_of_building
# 0                Flat
# 1                Flat
# 2                Flat
# 3                Flat
# 4                Flat
# ...               ...
# 6250             Flat
# 6251             Flat
# 6252             Flat
# 6253             Flat
# 6254             Flat
#
# [6255 rows x 13 columns]
#            price    area   latitude  longitude  Bedrooms  Bathrooms  Balcony
# 0     22400000.0   629.0  19.032800  72.896357       2.0        2.0      0.0  \
# 1     35000000.0   974.0  19.032800  72.896357       3.0        2.0      0.0
# 2     31700000.0   968.0  19.085600  72.909277       3.0        3.0      0.0
# 3     18700000.0   629.0  19.155756  72.846862       2.0        2.0      2.0
# 4     13500000.0  1090.0  19.177555  72.849887       2.0        2.0      0.0
# ...          ...     ...        ...        ...       ...        ...      ...
# 6250  19500000.0   810.0  19.138320  72.810020       2.0        2.0      0.0
# 6251  22000000.0  1400.0  19.221920  72.854250       3.0        3.0      1.0
# 6252  20000000.0   750.0  19.144320  72.824111       2.0        2.0      0.0
# 6253  11000000.0   700.0  19.047201  72.872225       2.0        2.0      0.0
# 6254  15000000.0   900.0  19.168818  72.936375       2.0        2.0      0.0
#
#       parking  Lift  Status_Ready to Move  Status_Under Construction
# 0         0.0   0.0                 False                       True  \
# 1         0.0   0.0                 False                       True
# 2         0.0   0.0                 False                       True
# 3         2.0   2.0                  True                      False
# 4         0.0   0.0                 False                      False
# ...       ...   ...                   ...                        ...
# 6250      0.0   0.0                  True                      False
# 6251      1.0   1.0                  True                      False
# 6252      0.0   0.0                  True                      False
# 6253      0.0   0.0                  True                      False
# 6254      0.0   0.0                  True                      False
#
#       neworold_New Property  neworold_Resale  Furnished_status_Furnished
# 0                      True            False                       False  \
# 1                      True            False                       False
# 2                      True            False                       False
# 3                      True            False                       False
# 4                      True            False                       False
# ...                     ...              ...                         ...
# 6250                  False             True                       False
# 6251                  False             True                       False
# 6252                  False             True                       False
# 6253                  False             True                        True
# 6254                  False             True                       False
#
#       Furnished_status_Semi-Furnished  Furnished_status_Unfurnished
# 0                               False                         False  \
# 1                               False                         False
# 2                               False                         False
# 3                               False                         False
# 4                               False                          True
# ...                               ...                           ...
# 6250                             True                         False
# 6251                            False                          True
# 6252                            False                         False
# 6253                            False                         False
# 6254                            False                         False
#
#       type_of_building_Flat  type_of_building_Individual House
# 0                      True                              False
# 1                      True                              False
# 2                      True                              False
# 3                      True                              False
# 4                      True                              False
# ...                     ...                                ...
# 6250                   True                              False
# 6251                   True                              False
# 6252                   True                              False
# 6253                   True                              False
# 6254                   True                              False
#
# [6255 rows x 18 columns]

# %%
#data = data.fillna(data.mode())
#print(df[['Status', 'Furnished_status']].mode())
#df['Status'] = df['Status']. fillna('Ready to Move')
#df['Furnished_status'] = df['Furnished_status']. fillna('Unfurnished')

print(pd.isnull(df).sum())
# Out:
# price                                0
# area                                 0
# latitude                             0
# longitude                            0
# Bedrooms                             0
# Bathrooms                            0
# Balcony                              0
# parking                              0
# Lift                                 0
# Status_Ready to Move                 0
# Status_Under Construction            0
# neworold_New Property                0
# neworold_Resale                      0
# Furnished_status_Furnished           0
# Furnished_status_Semi-Furnished      0
# Furnished_status_Unfurnished         0
# type_of_building_Flat                0
# type_of_building_Individual House    0
# dtype: int64

# %%
y = df["price"]
X = df.drop(["price"], axis=1)
display(y)
display(X)
# Out:
# 0       22400000.0
# 1       35000000.0
# 2       31700000.0
# 3       18700000.0
# 4       13500000.0
#            ...
# 6250    19500000.0
# 6251    22000000.0
# 6252    20000000.0
# 6253    11000000.0
# 6254    15000000.0
# Name: price, Length: 6255, dtype: float64
#         area   latitude  longitude  Bedrooms  Bathrooms  Balcony  parking
# 0      629.0  19.032800  72.896357       2.0        2.0      0.0      0.0  \
# 1      974.0  19.032800  72.896357       3.0        2.0      0.0      0.0
# 2      968.0  19.085600  72.909277       3.0        3.0      0.0      0.0
# 3      629.0  19.155756  72.846862       2.0        2.0      2.0      2.0
# 4     1090.0  19.177555  72.849887       2.0        2.0      0.0      0.0
# ...      ...        ...        ...       ...        ...      ...      ...
# 6250   810.0  19.138320  72.810020       2.0        2.0      0.0      0.0
# 6251  1400.0  19.221920  72.854250       3.0        3.0      1.0      1.0
# 6252   750.0  19.144320  72.824111       2.0        2.0      0.0      0.0
# 6253   700.0  19.047201  72.872225       2.0        2.0      0.0      0.0
# 6254   900.0  19.168818  72.936375       2.0        2.0      0.0      0.0
#
#       Lift  Status_Ready to Move  Status_Under Construction
# 0      0.0                 False                       True  \
# 1      0.0                 False                       True
# 2      0.0                 False                       True
# 3      2.0                  True                      False
# 4      0.0                 False                      False
# ...    ...                   ...                        ...
# 6250   0.0                  True                      False
# 6251   1.0                  True                      False
# 6252   0.0                  True                      False
# 6253   0.0                  True                      False
# 6254   0.0                  True                      False
#
#       neworold_New Property  neworold_Resale  Furnished_status_Furnished
# 0                      True            False                       False  \
# 1                      True            False                       False
# 2                      True            False                       False
# 3                      True            False                       False
# 4                      True            False                       False
# ...                     ...              ...                         ...
# 6250                  False             True                       False
# 6251                  False             True                       False
# 6252                  False             True                       False
# 6253                  False             True                        True
# 6254                  False             True                       False
#
#       Furnished_status_Semi-Furnished  Furnished_status_Unfurnished
# 0                               False                         False  \
# 1                               False                         False
# 2                               False                         False
# 3                               False                         False
# 4                               False                          True
# ...                               ...                           ...
# 6250                             True                         False
# 6251                            False                          True
# 6252                            False                         False
# 6253                            False                         False
# 6254                            False                         False
#
#       type_of_building_Flat  type_of_building_Individual House
# 0                      True                              False
# 1                      True                              False
# 2                      True                              False
# 3                      True                              False
# 4                      True                              False
# ...                     ...                                ...
# 6250                   True                              False
# 6251                   True                              False
# 6252                   True                              False
# 6253                   True                              False
# 6254                   True                              False
#
# [6255 rows x 17 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((4378, 17), (4378,), (1877, 17), (1877,))

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge

# %%
lr = LinearRegression().fit(X_train, y_train)
for item in zip(X_train.columns, lr.coef_.round()):
    print(item)

lr.predict(X_test)
# Out:
# ('area', 21195.0)
# ('latitude', -82380296.0)
# ('longitude', -73416203.0)
# ('Bedrooms', -312141.0)
# ('Bathrooms', 8838345.0)
# ('Balcony', -980.0)
# ('parking', -980.0)
# ('Lift', -980.0)
# ('Status_Ready to Move', 1912785.0)
# ('Status_Under Construction', 2911201.0)
# ('neworold_New Property', 232556.0)
# ('neworold_Resale', -232556.0)
# ('Furnished_status_Furnished', 1974775.0)
# ('Furnished_status_Semi-Furnished', -286473.0)
# ('Furnished_status_Unfurnished', -944897.0)
# ('type_of_building_Flat', 205230.0)
# ('type_of_building_Individual House', -205230.0)
# array([ 21843608.54528809, -11763810.00267792,  13004468.89345169, ...,
#         17614965.80083752,   7829504.38168812,  25584208.48747158])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from math import sqrt

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([ 21843608.54528809, -11763810.00267792,  13004468.89345169, ...,
#         17614965.80083752,   7829504.38168812,  25584208.48747158])

# %%
def MAE(y_test, y_predict):
    return np.sum(abs(y_test-y_predict))/len(y_test)

def MSE(y_test, y_predict):
    return np.sum((y_test - y_predict)**2) / len(y_test)

def RMSE(y_test, y_predict):
    return sqrt(MSE(y_test, y_predict))

def MAPE(y_test, y_predict):
    return np.mean(abs((y_test - y_predict) / y_test))

def R2(y_test, y_predict):
    return 1 - (MSE(y_test, y_predict) / (np.sum((y_test - y_test.mean())**2) / len(y_test)))

# %%
print(f'MAE: {mean_absolute_error(y_test, y_pred)}')
print(f'MSE: {mean_squared_error(y_test, y_pred)}')
print(f'RMSE: {sqrt(mean_squared_error(y_test, y_pred))}')
print(f'MAPE: {sqrt(mean_absolute_percentage_error(y_test, y_pred))}')
import numpy as np


print(f'MAE: {MAE(y_test, y_pred)}')
print(f'MSE: {MSE(y_test, y_pred)}')
print(f'RMSE: {RMSE(y_test, y_pred)}')
print(f'MAPE: {MAPE(y_test, y_pred)}')
print(f'R^2: {R2(y_test, y_pred)}')
print(f'R^2: {lr.score(X_test, y_test)}')
# Out:
# MAE: 9093826.143328836
# MSE: 252668411247444.6
# RMSE: 15895546.899916485
# MAPE: 0.7104926054761784
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 8
#       4 print(f'MAPE: {sqrt(mean_absolute_percentage_error(y_test, y_pred))}')
#       5 import numpy as np
# ----> 8 print(f'MAE: {MAE(y_test, y_pred)}')
#       9 print(f'MSE: {MSE(y_test, y_pred)}')
#      10 print(f'RMSE: {RMSE(y_test, y_pred)}')
#
# NameError: name 'MAE' is not defined

# %%
len(lr.coef_)
lr.coef_
# Out:
# array([ 2.11949626e+04, -8.23802958e+07, -7.34162030e+07, -3.12141186e+05,
#         8.83834494e+06, -9.79533467e+02, -9.79533467e+02, -9.79533468e+02,
#         1.91278483e+06,  2.91120103e+06,  2.32556059e+05, -2.32556059e+05,
#         1.97477467e+06, -2.86473103e+05, -9.44896777e+05,  2.05230389e+05,
#        -2.05230389e+05])

# %%
# L1
ridge = Ridge(alpha=0.06).fit(X_train, y_train)
y_pred = ridge.predict(X_test)
print(f'MAE: {mean_absolute_error(y_test, y_pred)}')
print(f'MSE: {mean_squared_error(y_test, y_pred)}')
print(f'RMSE: {sqrt(mean_squared_error(y_test, y_pred))}')
print(f'MAPE: {sqrt(mean_absolute_percentage_error(y_test, y_pred))}')
print(f'R^2: {ridge.score(X_test, y_test)}')
ridge.coef_
# Out:
# MAE: 9090075.73301757
# MSE: 252670026213400.1
# RMSE: 15895597.699155578
# MAPE: 0.7100651176433502
# R^2: 0.6774693491970193
# array([ 2.11979645e+04, -8.22708710e+07, -7.31085588e+07, -3.14061343e+05,
#         8.84287171e+06, -1.58188254e+03, -1.58188254e+03, -1.58188254e+03,
#         1.91233045e+06,  2.74035456e+06,  2.31831681e+05, -2.31831681e+05,
#         1.97784718e+06, -2.87879531e+05, -9.46499753e+05,  2.05249531e+05,
#        -2.05249531e+05])

# %%
# L2
lasso = Lasso(alpha=0.4).fit(X_train, y_train)
y_pred = lasso.predict(X_test)
#print(np.mean(abs(y_test-y_pred)))
print(f'MAE: {mean_absolute_error(y_test, y_pred)}')
print(f'MSE: {mean_squared_error(y_test, y_pred)}')
print(f'RMSE: {sqrt(mean_squared_error(y_test, y_pred))}')
print(f'MAPE: {sqrt(mean_absolute_percentage_error(y_test, y_pred))}')
print(f'R^2: {lasso.score(X_test, y_test)}')
lasso.coef_
# Out:
# MAE: 9093826.420252543
# MSE: 252668425413162.97
# RMSE: 15895547.345504116
# MAPE: 0.7104924928736209
# R^2: 0.677471392601811
# array([ 2.11949621e+04, -8.23802606e+07, -7.34160795e+07, -3.12137703e+05,
#         8.83834393e+06, -2.93904713e+03, -2.31758858e-10, -1.64871180e-10,
#         1.91277203e+06,  2.90943700e+06,  4.65107529e+05, -3.98918364e-10,
#         1.97477230e+06, -2.86473246e+05, -9.44898405e+05,  4.10454509e+05,
#        -6.28254060e-10])

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
#import numpy as np

# %%
parameters = {'alpha': np.arange(0, 1, 0.1)}
ridge_optimal = GridSearchCV(Ridge(), parameters).fit(X_train, y_train)
ridge_optimal.best_params_
# Out:
# {'alpha': 0.1}

# %%
ridge_optimal = RandomizedSearchCV(Ridge(), parameters).fit(X_train, y_train)
ridge_optimal.best_params_
# Out:
# {'alpha': 0.1}

# %%
X = X_train.values.reshape(-1,17)
y = y_train.values.reshape(-1,1)


X_te = X_test.values.reshape(-1,17)
y_te = y_test.values.reshape(-1,1)


lr = LinearRegression().fit(X, y)

# %%
from sklearn.preprocessing import PolynomialFeatures
# создаем объект, который позволит расширить множество предикторов
pf = PolynomialFeatures(2)
# добавляем новые предикторы
X_p=pf.fit_transform(X)

X_p_train = pf.fit_transform(X) 
X_p_test = pf.fit_transform(X_te)

# %%
lr2 = LinearRegression().fit(X_p_train, y)

# %%
y_pred = lr2.predict(X_p_test)
print(f'R^2: {lr2.score(y_te, y_pred)}')
y_pred
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 2
#       1 y_pred = lr2.predict(X_p_test)
# ----> 2 print(f'R^2: {lr2.score(y_te, y_pred)}')
#       3 y_pred
#
# File ~\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\base.py:722, in RegressorMixin.score(self, X, y, sample_weight)
#     680 """Return the coefficient of determination of the prediction.
#     681
#     682 The coefficient of determination :math:`R^2` is defined as
#    (...)
#     717 :class:`~sklearn.multioutput.MultiOutputRegressor`).
#     718 """
#     720 from .metrics import r2_score
# --> 722 y_pred = self.predict(X)
#     723 return r2_score(y, y_pred, sample_weight=sample_weight)
#
# File ~\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_base.py:354, in LinearModel.predict(self, X)
#     340 def predict(self, X):
#     341     """
#     342     Predict using the linear model.
#     343
#    (...)
#     352         Returns predicted values.
#     353     """
# --> 354     return self._decision_function(X)
#
# File ~\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_base.py:337, in LinearModel._decision_function(self, X)
#     334 def _decision_function(self, X):
#     335     check_is_fitted(self)
# --> 337     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     338     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# File ~\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\base.py:588, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     585     out = X, y
#     587 if not no_val_X and check_params.get("ensure_2d", True):
# --> 588     self._check_n_features(X, reset=reset)
#     590 return out
#
# File ~\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\base.py:389, in BaseEstimator._check_n_features(self, X, reset)
#     386     return
#     388 if n_features != self.n_features_in_:
# --> 389     raise ValueError(
#     390         f"X has {n_features} features, but {self.__class__.__name__} "
#     391         f"is expecting {self.n_features_in_} features as input."
#     392     )
#
# ValueError: X has 1 features, but LinearRegression is expecting 171 features as input.

# %%
parameters = {'alpha': np.arange(0, 1, 0.1)}
ridge_optimal = GridSearchCV(Ridge(), parameters).fit(X_p_train, y)

lasso_optimal = GridSearchCV(Lasso(), parameters).fit(X_p_train, y)
# Out:
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.97443e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.86491e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.04917e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.90975e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.73021e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=3.94744e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=3.72867e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=4.09681e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=3.81823e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=3.4593e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=5.91949e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=5.59159e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.14328e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=5.72563e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=5.18749e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.89069e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.45371e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.18869e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.63204e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.91486e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=9.86111e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=9.31508e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.0233e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=9.53748e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.64135e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.18308e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.11757e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.22762e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.14419e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.0367e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.37998e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.30357e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.43186e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.33455e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.20919e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.57682e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.48951e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.63599e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.52481e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.3816e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.7736e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.67538e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.84003e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.71499e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.55393e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=4.55724e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\model_selection\_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.857e+17, tolerance: 2.485e+14 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\model_selection\_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.256e+17, tolerance: 2.848e+14 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\model_selection\_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.973e+17, tolerance: 2.729e+14 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\model_selection\_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.791e+17, tolerance: 2.608e+14 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\model_selection\_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.187e+17, tolerance: 2.903e+14 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.857e+17, tolerance: 2.485e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.256e+17, tolerance: 2.848e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.973e+17, tolerance: 2.729e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.791e+17, tolerance: 2.608e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.187e+17, tolerance: 2.903e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.857e+17, tolerance: 2.485e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.256e+17, tolerance: 2.848e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.973e+17, tolerance: 2.729e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.791e+17, tolerance: 2.608e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.187e+17, tolerance: 2.903e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.857e+17, tolerance: 2.485e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.256e+17, tolerance: 2.848e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.973e+17, tolerance: 2.729e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.791e+17, tolerance: 2.608e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.187e+17, tolerance: 2.903e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.857e+17, tolerance: 2.485e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.256e+17, tolerance: 2.848e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.973e+17, tolerance: 2.729e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.791e+17, tolerance: 2.608e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.187e+17, tolerance: 2.903e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.857e+17, tolerance: 2.485e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.256e+17, tolerance: 2.848e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.973e+17, tolerance: 2.729e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.791e+17, tolerance: 2.608e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.187e+17, tolerance: 2.903e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.857e+17, tolerance: 2.485e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.256e+17, tolerance: 2.848e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.973e+17, tolerance: 2.729e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.791e+17, tolerance: 2.608e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.187e+17, tolerance: 2.903e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.857e+17, tolerance: 2.485e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.256e+17, tolerance: 2.848e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.973e+17, tolerance: 2.729e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.791e+17, tolerance: 2.608e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.187e+17, tolerance: 2.903e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.857e+17, tolerance: 2.485e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.256e+17, tolerance: 2.848e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.973e+17, tolerance: 2.729e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.791e+17, tolerance: 2.608e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.187e+17, tolerance: 2.903e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.857e+17, tolerance: 2.485e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.256e+17, tolerance: 2.848e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.973e+17, tolerance: 2.729e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.791e+17, tolerance: 2.608e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.187e+17, tolerance: 2.903e+14
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.116e+17, tolerance: 3.394e+14
#   model = cd_fast.enet_coordinate_descent(

# %%
# L1
print(ridge_optimal.best_params_['alpha'])
ridge = Ridge(alpha=ridge_optimal.best_params_['alpha']).fit(X_p_train, y)
y_pred = ridge.predict(X_p_test)
#y_pred = y_d
print(f'MAE: {MAE(y_te, y_pred)}')
print(f'MSE: {MSE(y_te, y_pred)}')
print(f'RMSE: {RMSE(y_te, y_pred)}')
print(f'MAPE: {MAPE(y_te, y_pred)}')
print(f'R^2: {ridge.score(X_p_train, y)}')


#ridge.coef_
# Out:
# 0.30000000000000004
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=4.55724e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 6
#       4 y_pred = ridge.predict(X_p_test)
#       5 #y_pred = y_d
# ----> 6 print(f'MAE: {MAE(y_te, y_pred)}')
#       7 print(f'MSE: {MSE(y_te, y_pred)}')
#       8 print(f'RMSE: {RMSE(y_te, y_pred)}')
#
# NameError: name 'MAE' is not defined

# %%
# L2
lasso = Lasso(alpha=lasso_optimal.best_params_['alpha']).fit(X_p_train, y)
y_pred = lasso.predict(X_p_test)

print(f'MAE: {MAE(y_te, y_pred)}')
print(f'MSE: {MSE(y_te, y_pred)}')
print(f'RMSE: {RMSE(y_te, y_pred)}')
print(f'MAPE: {MAPE(y_te, y_pred)}')
print(f'R^2: {lasso.score(X_p_train, y)}')




#lasso.coef_
# Out:
# C:\Users\verab\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.116e+17, tolerance: 3.394e+14
#   model = cd_fast.enet_coordinate_descent(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 5
#       2 lasso = Lasso(alpha=lasso_optimal.best_params_['alpha']).fit(X_p_train, y)
#       3 y_pred = lasso.predict(X_p_test)
# ----> 5 print(f'MAE: {MAE(y_te, y_pred)}')
#       6 print(f'MSE: {MSE(y_te, y_pred)}')
#       7 print(f'RMSE: {RMSE(y_te, y_pred)}')
#
# NameError: name 'MAE' is not defined

# %%
class LR:

    def init(self, alpha):
        self.learning_rate = lr
        self.weights = None
        self.bias = None
        
    def mserror_mat(X, w, y):
        y_pred = X @ w
        return np.sum((y - y_pred) ** 2) / len(y_pred)

    # функция градиента
    def gr_mserror_mat(X, w, y):
        y_pred = X @ w
        return 2/len(X)*(y - y_pred) @ (-X)

    def fit(self, X, y, n_iters = 100, learning_rate = 0.1):
        #n_samples, n_features = X.shape
        X = np.column_stack([X, np.ones((X.shape[0]))])
        self.weights = np.zeros(X.shape[1])
        next_weights = self.weights

        for _ in range(n_iters):
            cur_weights = next_weights
            
            next_weights = cur_weights - learning_rate * gr_mserror_mat(X, cur_weights, y)
            
            if np.linalg.norm(cur_weights - next_weights, ord=2) <= eps:
              break
            
           #y_pred = np.dot(X, self.weights) + self.bias

            '''dw = (1/n_samples) * np.dot(X.T, (y_pred-y))
            db = (1/n_samples) * np.sum(y_pred-y)

            self.weights = self.weights - self.lr * dw
            self.bias = self.bias - self.lr * db'''

    def predict(self, X):
        y_pred = np.dot(X, self.weights) + self.bias
        return y_pred

# %%
class RidgeLinearRegression:
    def __init__(self, alpha=1.0):
        self.alpha = alpha

    def fit(self, X, y):
        m, n = X.shape
        X_b = np.c_[np.ones((m, 1)), X]

        # calculate the normal equations with ridge regularization
        A = np.eye(n+1)
        A[0, 0] = 0
        A[1:, 1:] = self.alpha * np.identity(n)
        self.theta = np.linalg.inv(X_b.T.dot(X_b) + A).dot(X_b.T).dot(y)

    def predict(self, X):
        m, n = X.shape
        X_b = np.c_[np.ones((m, 1)), X]
        return X_b.dot(self.theta)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((4378, 17), (4378,), (1877, 17), (1877,))

# %%
model = LinearRegression()
model

y = df["price"]
X = df.drop(["price"], axis=1)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
model.fit(X_train, y_train)

#model.predict(X_test)

df = pd.DataFrame(X_train)
df['y'] = y_train
df['pred_fit'] = model.predict(X_test)
df['pred_dot'] = X_train.dot(model.coef_) + model.intercept_
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 7
#       5 df = pd.DataFrame(X_train)
#       6 df['y'] = y_train
# ----> 7 df['pred_fit'] = model.predict(X_test)
#       8 df['pred_dot'] = X_train.dot(model.coef_) + model.intercept_
#       9 df.head()
#
# File ~\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\pandas\core\frame.py:3960, in DataFrame.__setitem__(self, key, value)
#    3957     self._setitem_array([key], value)
#    3958 else:
#    3959     # set column
# -> 3960     self._set_item(key, value)
#
# File ~\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\pandas\core\frame.py:4153, in DataFrame._set_item(self, key, value)
#    4143 def _set_item(self, key, value) -> None:
#    4144     """
#    4145     Add series to DataFrame in specified column.
#    4146
#    (...)
#    4151     ensure homogeneity.
#    4152     """
# -> 4153     value = self._sanitize_column(value)
#    4155     if (
#    4156         key in self.columns
#    4157         and value.ndim == 1
#    4158         and not is_extension_array_dtype(value)
#    4159     ):
#    4160         # broadcast across multiple columns if necessary
#    4161         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\pandas\core\frame.py:4880, in DataFrame._sanitize_column(self, value)
#    4877     return _reindex_for_setitem(Series(value), self.index)
#    4879 if is_list_like(value):
# -> 4880     com.require_length_match(value, self.index)
#    4881 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File ~\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\pandas\core\common.py:576, in require_length_match(data, index)
#     572 """
#     573 Check the length of data matches the length of the index.
#     574 """
#     575 if len(data) != len(index):
# --> 576     raise ValueError(
#     577         "Length of values "
#     578         f"({len(data)}) "
#     579         "does not match length of index "
#     580         f"({len(index)})"
#     581     )
#
# ValueError: Length of values (1877) does not match length of index (4378)

# %%
class mRidgeRegression:
    def __init__(self, alpha=1.0, fit_intercept=True):
        self.alpha = alpha
        self.fit_intercept = fit_intercept
        self.coef_ = None
        self.intercept_ = None

    def fit(self, X, y):
        if self.fit_intercept:
            X = np.insert(X, 0, 1, axis=1)

        n_samples, n_features = X.shape

        # Ridge regularization matrix
        I = np.identity(n_features)
        I[0, 0] = 0

        # Normal equation
        self.coef_ = np.linalg.inv(X.T.dot(X) + self.alpha * I).dot(X.T).dot(y)

        if self.fit_intercept:
            self.intercept_ = self.coef_[0]
        self.coef_ = self.coef_[1:]

    def predict(self, X):
        if self.fit_intercept:
            X = np.insert(X, 0, 1, axis=1)
        return X.dot(self.coef_) + self.intercept_

# %%
regression = mRidgeRegression(alpha=0.1)
regression.fit(X_train, y_train)
y_pred = regression.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[41], line 2
#       1 regression = mRidgeRegression(alpha=0.1)
# ----> 2 regression.fit(X_train, y_train)
#       3 y_pred = regression.predict(X_test)
#
# Cell In[40], line 19, in mRidgeRegression.fit(self, X, y)
#      16 I[0, 0] = 0
#      18 # Normal equation
# ---> 19 self.coef_ = np.linalg.inv(X.T.dot(X) + self.alpha * I).dot(X.T).dot(y)
#      21 if self.fit_intercept:
#      22     self.intercept_ = self.coef_[0]
#
# File <__array_function__ internals>:180, in inv(*args, **kwargs)
#
# File ~\Desktop\не долги\4 семестр\ML\venv\lib\site-packages\numpy\linalg\linalg.py:552, in inv(a)
#     550 signature = 'D->D' if isComplexType(t) else 'd->d'
#     551 extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 552 ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     553 return wrap(ainv.astype(result_t, copy=False))
#
# UFuncTypeError: Cannot cast ufunc 'inv' input from dtype('O') to dtype('float64') with casting rule 'same_kind'
